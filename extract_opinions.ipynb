# %%
from crewai_tools import SeleniumScrapingTool
import json 
import os

# Example 1: Initialize the tool without any parameters to scrape the current page it navigates to
tool = SeleniumScrapingTool()

with open('opinion_data_va_ct.json', 'r') as f:
    data_opinions = json.load(f)

for opinion in data_opinions:
    opinion_url = opinion['opinion_url']
    tool = SeleniumScrapingTool(website_url=opinion_url, css_element='.tab-content')
    text = tool.run()
    try:
        case = opinion["case_name"].replace('/','')[:20]
        with open(f'opinion_text_va/{opinion["id"]}_{case}.txt', 'w') as f:
            f.write(text)
        print(f'Opinion {opinion["id"]} saved')
    except FileNotFoundError as e:
        print(f"FileNotFoundError: {e}")
# Out:
# Using Tool: Read a website content
# Opinion 9996927 saved
# Using Tool: Read a website content
# Opinion 9996926 saved
# Using Tool: Read a website content
# Opinion 9932334 saved
# Using Tool: Read a website content
# Opinion 9593274 saved
# Using Tool: Read a website content
# Opinion 9593259 saved
# Using Tool: Read a website content
# Opinion 9511593 saved
# Using Tool: Read a website content
# Opinion 9508865 saved
# Using Tool: Read a website content
# Opinion 9500658 saved
# Using Tool: Read a website content
# Opinion 9500657 saved
# Using Tool: Read a website content
# Opinion 9500659 saved
# Using Tool: Read a website content
# Opinion 9498715 saved
# Using Tool: Read a website content
# Opinion 9497852 saved
# Using Tool: Read a website content
# Opinion 9494580 saved
# Using Tool: Read a website content
# Opinion 9492621 saved
# Using Tool: Read a website content
# Opinion 9490736 saved
# Using Tool: Read a website content
# Opinion 9490735 saved
# Using Tool: Read a website content
# Opinion 9483864 saved
# Using Tool: Read a website content
# Opinion 9483863 saved
# Using Tool: Read a website content
# Opinion 9479501 saved
# Using Tool: Read a website content
# Opinion 1060156 saved
# Using Tool: Read a website content
# Opinion 6924415 saved
# Using Tool: Read a website content
# Opinion 1059862 saved
# Using Tool: Read a website content
# Opinion 1059244 saved
# Using Tool: Read a website content
# Opinion 6924481 saved
# Using Tool: Read a website content
# Opinion 6924805 saved
# Using Tool: Read a website content
# Opinion 9475201 saved
# Using Tool: Read a website content
# Opinion 9473194 saved
# Using Tool: Read a website content
# Opinion 9461601 saved
# Using Tool: Read a website content
# Opinion 9451982 saved
# Using Tool: Read a website content
# Opinion 9451981 saved
# Using Tool: Read a website content
# Opinion 9451980 saved
# Using Tool: Read a website content
# Opinion 9447935 saved
# Using Tool: Read a website content
# Opinion 9443890 saved
# Using Tool: Read a website content
# Opinion 9439842 saved
# Using Tool: Read a website content
# Opinion 9439841 saved
# Using Tool: Read a website content
# Opinion 9433820 saved
# Using Tool: Read a website content
# Opinion 9433819 saved
# Using Tool: Read a website content
# Opinion 9433818 saved
# Using Tool: Read a website content
# Opinion 9432253 saved
# Using Tool: Read a website content
# Opinion 4657240 saved
# Using Tool: Read a website content
# Opinion 4656694 saved
# Using Tool: Read a website content
# Opinion 4655942 saved
# Using Tool: Read a website content
# Opinion 4655506 saved
# Using Tool: Read a website content
# Opinion 4655370 saved
# Using Tool: Read a website content
# Opinion 4654798 saved
# Using Tool: Read a website content
# Opinion 4654797 saved
# Using Tool: Read a website content
# Opinion 4654796 saved
# Using Tool: Read a website content
# Opinion 4648502 saved
# Using Tool: Read a website content
# Opinion 4648501 saved
# Using Tool: Read a website content
# Opinion 4648500 saved
# Using Tool: Read a website content
# Opinion 4644764 saved
# Using Tool: Read a website content
# Opinion 4644763 saved
# Using Tool: Read a website content
# Opinion 4640569 saved
# Using Tool: Read a website content
# Opinion 4640568 saved
# Using Tool: Read a website content
# Opinion 4640567 saved
# Using Tool: Read a website content
# Opinion 4640565 saved
# Using Tool: Read a website content
# Opinion 4636314 saved
# Using Tool: Read a website content
# Opinion 4633397 saved
# Using Tool: Read a website content
# Opinion 4633396 saved
# Using Tool: Read a website content
# Opinion 4633395 saved
